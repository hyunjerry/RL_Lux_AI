# %%
from google.colab import drive
import os

drive.mount('/content/drive')
# %cd '/content/drive/My Drive/RL HW4'
print(os.getcwd())
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/My Drive/RL HW4
# /content/drive/My Drive/RL HW4

# %%
# !pip install git+https://github.com/glmcdona/LuxPythonEnvGym.git
# !pip install kaggle-environments -U
# Out:
# ...
#   Cloning https://github.com/glmcdona/LuxPythonEnvGym.git to /tmp/pip-req-build-h8r9hf9j
#   Running command git clone --filter=blob:none --quiet https://github.com/glmcdona/LuxPythonEnvGym.git /tmp/pip-req-build-h8r9hf9j
#   Resolved https://github.com/glmcdona/LuxPythonEnvGym.git to commit 55e8ddc15012fd55f17b23aa2e73c919467e43e3
#   Preparing metadata (setup.py) ... done
# ...
#   Using cached stable_baselines3-1.2.1a2-py3-none-any.whl (173 kB)
# ...
#   Using cached gym-0.19.0.tar.gz (1.6 MB)
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   Preparing metadata (setup.py) ... error
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.
# ...

# %% [markdown]
# # Beat the Midterm Champion
#
# This is a notebook uses the Kaggle Lux AI environment to run your agent and the Midterm Champion in a game. Your agent is represented by Player 0. Midterm Champion is represented as Player 1.
#
# To Run, unzip your model from your kaggle submission zip file in the same folder as this notebook. So that your folder structure looks like this:
#
#     v HW4
#     |-- HW4.ipynb
#     |-- UNet_attention >
#     |--v my_agent >
#     |--|-- main.py
#
#
# Replace the first entry in agent variable in the next code section to point to the main.py of your submission code.
#
# Run for a 100 episodes and show that you win more than 50 of such episodes.

# %%
from kaggle_environments import make, evaluate
import numpy as np
from tqdm import tqdm

environment = "lux_ai_2021"
steps = []

##################
# Which agents to run repeatedly.  Same as env.run(agents)
# with Midterm Champions
# agents = ["./UNet_attention/main.py", "./UNet_attention_jason_0-3_ensemble/main.py"]
        #  ---------------------------- <- replace the underlined section with path to your agent

# with Transformer
agents = ["./transformer/main.py" , "./UNet_attention_jason_0-3_ensemble/main.py"]
#          ---------------------------- <- replace the underlined section with path to your agent

# with non-ensemble models
# agents = ["./UNet_attention_Ablation_study/main.py" , "./UNet_attention_jason_0-3_ensemble/main.py"]
        #  ---------------------------- <- replace the underlined section with path to your agent

# How many times to run them.
# num_episodes = 100
num_episodes = 1

rewards = [[] for i in range(num_episodes)]
envs = [[] for i in range(num_episodes)]
wins = [[] for i in range(num_episodes)]
for i in tqdm(range(num_episodes), total=num_episodes):
  configuration = {"seed": i, "loglevel": 2, "annotations": True}
  envs[i] = make(environment, configuration, steps, debug=False)
  last_state = envs[i].run(agents)[-1]
  rewards[i] = [state.reward if state.reward is not None else 0 for state in last_state]

wins = np.argmax(rewards, axis=1)
games_won = np.count_nonzero(wins == 0)
print(f'Number of games won by your agent: {games_won}')
print('Pass' if games_won > (0.5 * num_episodes) else 'Fail')
# Out:
# 100%|██████████| 1/1 [00:00<00:00,  1.67it/s]
# Number of games won by your agent: 1
# Pass

# %%
# Render any specific match
# Use this for debugging or getting more insight for training
# Select a match
matchId = 0
#
env = envs[matchId]
env.render(mode="ipython", width=600, height=400)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# <iframe srcdoc="<!DOCTYPE html>
# <html lang=&quot;en&quot;>
#   <head>
#     <script>
#
# window.kaggle = {
#   &quot;debug&quot;: false,
#   &quot;playing&quot;: true,
#   &quot;step&quot;: 0,
#   &quot;controls&quot;: true,
#   &quot;environment&quot;: {
#     &quot;id&quot;: &quot;812a5b42-07d2-11ef-be68-0242ac1c000c&quot;,
#     &quot;name&quot;: &quot;lux_ai_2021&quot;,
#     &quot;title&quot;: &quot;Lux AI Challenge: 2021&quot;,
#     &quot;description&quot;: &quot;A Novel AI Programming Challenge about Lux&quot;,
#     &quot;version&quot;: &quot;3.1.0&quot;,
#     &quot;configuration&quot;: {
#       &quot;seed&quot;: 0,
# ...
